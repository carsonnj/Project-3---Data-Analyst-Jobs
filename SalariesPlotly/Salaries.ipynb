# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path
import plotly.graph_objects as go
import json
import matplotlib.ticker as mticker

# %%
salary_df= pd.read_csv("../Resources/Salary_Data_Cleaned.csv")
salary_df
# Out:
#       Age  Gender Education Level                  Job Title  \
# 0      24    Male        Master's         Back end Developer
# 1      22  Female     High School         Back end Developer
# 2      24    Male        Master's         Back end Developer
# 3      22  Female     High School         Back end Developer
# 4      23  Female      Bachelor's    Senior Project Engineer
# ...   ...     ...             ...                        ...
# 4168   60  Female             PhD  Software Engineer Manager
# 4169   57  Female             PhD  Software Engineer Manager
# 4170   57  Female        Master's        Full Stack Engineer
# 4171   60  Female             PhD  Software Engineer Manager
# 4172   60  Female             PhD  Software Engineer Manager
#
#       Years of Experience  Salary
# 0                     0.0   55538
# 1                     0.0   51832
# 2                     0.0   55538
# 3                     0.0   51832
# 4                     0.0   51831
# ...

# %%
years_of_exp = salary_df.groupby('Years of Experience')['Salary'].mean().reset_index()
years_of_exp['Salary'] = years_of_exp['Salary'].round(0).astype(int)

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(years_of_exp['Years of Experience'], years_of_exp['Salary'], marker='o', color='blue', linestyle='-')
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary')
plt.title('Average Salary per Years of Experience (Line Chart)')
plt.grid(True)
plt.show()

# %%
json_data = years_of_exp.to_json(orient='records')

# Save the JSON data to a file
with open('years_exp.json', 'w') as json_file:
    json_file.write(json_data)
years_of_exp
# Out:
#     Years of Experience  Salary
# 0                   0.0   50331
# 1                   1.0   60100
# 2                   1.5   40000
# 3                   2.0   67567
# 4                   3.0   83249
# 5                   4.0   94347
# 6                   5.0  113658
# 7                   6.0  127538
# 8                   7.0  131831
# 9                   8.0  140756
# 10                  9.0  150643
# 11                 10.0  144815
# 12                 11.0  172547
# 13                 12.0  165667
# 14                 13.0  162133
# 15                 14.0  172379
# 16                 15.0  165565
# 17                 16.0  179700
# 18                 17.0  187637
# 19                 18.0  188335
# 20                 19.0  182257
# 21                 20.0  170584
# 22                 21.0  174261
# 23                 22.0  194902
# 24                 23.0  189154
# 25                 24.0  209071
# 26                 25.0  174633
# 27                 26.0  187717
# ...

# %%
education_level = salary_df.groupby('Education Level')['Salary'].mean().reset_index()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(education_level['Education Level'], education_level['Salary'], color='blue')
plt.xlabel('Education Level')
plt.ylabel('Average Salary')
plt.title('Average Salary by Education Level')
plt.show()

# %%
json_data = education_level.to_json(orient='records')

# Save the JSON data to a file
with open('education_level.json', 'w') as json_file:
    json_file.write(json_data)
    
education_level
# Out:
#   Education Level         Salary
# 0      Bachelor's  100254.319941
# 1     High School   90314.975000
# 2        Master's  134867.264477
# 3             PhD  176750.018182
